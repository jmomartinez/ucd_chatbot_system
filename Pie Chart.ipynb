# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'Campus Ready (Covid)', 'Graduate Studies Application', 'Student Housing', 'CS Graduate Studies'

# Total Characters:  91211
# Total QA Pairs:  227

sizes = [102, 80, 14, 31]
colors = ['darkorange', 'gold', 'palevioletred', 'maroon']
#explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=70)
plt.title('FAQ Data Distribution')
plt.axis('equal')
plt.savefig('pieChart.png')
plt.show()
